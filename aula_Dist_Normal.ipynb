# %%
import numpy as np
import pandas as pd
from scipy.stats import norm
import matplotlib.pyplot as plt

# %% [markdown]
# ## Distribuição normal - exemplo
#
# A situação abaixo mostra uma distribuição normal de média 7 e com desvios padrão de 1,0 e 2,0 para exemplificar a diferença das curvas.

# %%
med = 7
std = 2
med2 = 7
std2 = 1
x = np.linspace(0,14,num=1000)

plt.figure(figsize=(8,6))
plt.plot(x, norm.pdf(x,med,std),
        label = '$\mathcal{N}$  ' + f'$( \mu = {med:.2f} , \sigma = {std:.2f} )$')
plt.plot(x, norm.pdf(x,med2,std2), 'r',
        label = '$\mathcal{N}$  ' + f'$( \mu = {med2:.2f} , \sigma = {std2:.2f} )$')
plt.title('Distribuição Normal')
plt.xlabel('Valores')
plt.ylabel('Densidade de Probabilidade')
plt.legend()
plt.show()

# %% [markdown]
# ## Distribuição normal padrão
#
# São mostradas 3 curvas distintas para visualização da média (pico da curva) e desvio padrão (largura-altura da curva)

# %%
med = 0
std = 1
med2 = 0
std2 = 2.0
med3 = 2
std3 = 1
x = np.linspace(-6,6,num=1000)

plt.figure(figsize=(8,6))
plt.plot(x, norm.pdf(x,med,std),
        label = '$\mathcal{N}$  ' + f'$( \mu = {med:.2f} , \sigma = {std:.2f} )$',linewidth=2.0)
plt.plot(x, norm.pdf(x,med2,std2), 'r',
        label = '$\mathcal{N}$  ' + f'$( \mu = {med2:.2f} , \sigma = {std2:.2f} )$',linewidth=2.0)
plt.plot(x, norm.pdf(x,med3,std3), 'g',
        label = '$\mathcal{N}$  ' + f'$( \mu = {med3:.2f} , \sigma = {std3:.2f} )$',linewidth=2.0)
plt.ylim(0,0.45)
plt.title('Distribuição Normal Padrão')
plt.xlabel('Valores')
plt.ylabel('Densidade de Probabilidade')
plt.legend()
plt.show()
